# %% [markdown]
# <a href="https://colab.research.google.com/github/it25101550/AI-ML-Project-16/blob/IT25101527/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================
# CELL 01 - IMPORTING LIBRARIES
# ==============================================================

# System & File Handling
import os
import joblib
import warnings
from google.colab import files

# Data Handling & Analytics
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing & Model Selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.exceptions import InconsistentVersionWarning

# ML Classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# Metrics
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report
)

warnings.filterwarnings('ignore')
print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
# CELL 02 - LOADING THE DATASET
# ==============================================================

# 1. Upload CSV dataset
print("Upload 'fitness_dataset.csv' or 'fitness_dataset_2.csv':")
uploaded = files.upload()

filename = list(uploaded.keys())[0]

# 2. Load dataset into DataFrame
df = pd.read_csv(filename)

# 3. Overview of dataset characteristics
print("\n--- Dataset Summary ---")
print(f"Total Rows: {df.shape[0]}, Total Columns: {df.shape[1]}")
print("\nColumn Data Types & Missing Values:")
print(df.info())

print("\nFirst 5 Rows:")
display(df.head())

print("\nTarget Variable Distribution ('is_fit'):")
print(df['is_fit'].value_counts())
# Out:
# Upload 'fitness_dataset.csv' or 'fitness_dataset_2.csv':
#      <input type="file" id="files-b54e791b-93a0-4c6c-a60f-38964392f052" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b54e791b-93a0-4c6c-a60f-38964392f052">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# ==============================================================
# CELL 03 - EDA
# EDA VISUALIZATION: CORRELATION HEATMAP - Feature correlation matrix
# ==============================================================

# Set visual style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(9, 7))

# Plot 4: Correlation Heatmap
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap='coolwarm', cbar=False)
plt.title("Feature Correlation Matrix")

plt.tight_layout()
plt.show()

# %%
# ==============================================================
# CELL 04 - PREPROCESSING
# MEMBER 2 | TECHNIQUE: FEATURE / TARGET SEPARATION + FEATURE
# CATEGORIZATION (numerical vs categorical feature selection)
# ==============================================================

# 1. Standardize string inconsistencies in categorical feature 'smokes'
#    (carried over from Member 1 - required before splitting)
df['smokes'] = df['smokes'].astype(str).str.lower().replace({'0': 'no', '1': 'yes'})

# ---- MEMBER 2 OWN WORK STARTS HERE ----

# 2. Separate features (X) and target variable (y)
X = df.drop(columns=['is_fit'])
y = df['is_fit']

# Feature categorizations
num_cols = ['age', 'height_cm', 'weight_kg', 'heart_rate', 'blood_pressure',
            'sleep_hours', 'nutrition_quality', 'activity_index']
cat_cols = ['smokes', 'gender']

# Verification output for the viva
print("Feature matrix shape:", X.shape)
print("Target vector shape:", y.shape)
print("Numerical features:", num_cols)
print("Categorical features:", cat_cols)
# Out:
# Feature matrix shape: (2000, 10)
# Target vector shape: (2000,)
# Numerical features: ['age', 'height_cm', 'weight_kg', 'heart_rate', 'blood_pressure', 'sleep_hours', 'nutrition_quality', 'activity_index']
# Categorical features: ['smokes', 'gender']

# %%
plt.figure(figsize=(8, 6))
feature_counts = pd.Series({'Numerical': len(num_cols), 'Categorical': len(cat_cols)})
sns.barplot(x=feature_counts.index, y=feature_counts.values, palette='Set3')
plt.title("Feature Type Breakdown After Categorization")
plt.xlabel("Feature Type")
plt.ylabel("Number of Features")
plt.tight_layout()
plt.show()

# %%
# ==============================================================
# CELL 05 - DOWNLOADING THE FILE
# ==============================================================

features_out = 'member2_features_X.csv'
target_out = 'member2_target_y.csv'

X.to_csv(features_out, index=False)
y.to_csv(target_out, index=False)

print(f"✅ Saved '{features_out}' and '{target_out}'")
files.download(features_out)
files.download(target_out)
# Out:
# ✅ Saved 'member2_features_X.csv' and 'member2_target_y.csv'
